# %% [markdown]
# # Lab 7- Deep Learning Model
#
# This lab is meant to get you started in using Keras to design Deep Neural Networks. The goal here is to simply repeat your previous lab, but with DNNs.
#
# Let's start with reading the data, like before:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

filename="../Lab5/SUSY.csv"
VarNames=["signal", "l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]
RawNames=["l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi","MET", "MET_phi", "MET_rel", "axial_MET"]
FeatureNames=["M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]

df = pd.read_csv(filename, dtype='float64', names=VarNames)

# %% [markdown]
# Now lets define training and test samples. Note that DNNs take very long to train, so for testing purposes we will use only about 10% of the 5 million events in the training/validation sample. Once you get everything working, make the final version of your plots with the full sample.
#
# Also note that Keras had trouble with the Pandas tensors, so after doing all of the nice manipulation that Pandas enables, we convert the Tensor to a regular numpy tensor.

# %%
N_Max=550000
N_Train=500000

Train_Sample=df[:N_Train]
Test_Sample=df[N_Train:N_Max]

X_Train=np.array(Train_Sample[VarNames[1:]])
y_Train=np.array(Train_Sample["signal"])

X_Test=np.array(Test_Sample[VarNames[1:]])
y_Test=np.array(Test_Sample["signal"])

# %%
Test_Sample[RawNames]
# Out:
#           l_1_pT   l_1_eta   l_1_phi    l_2_pT   l_2_eta   l_2_phi       MET  \
# 500000  0.668017 -1.013524  1.661522  0.806839  0.265961 -0.168963  1.340346
# 500001  0.758622 -1.889814 -0.450389  0.515570 -1.337005  1.516792  0.808083
# 500002  0.493883  0.913933  0.694969  0.570579 -0.347849 -0.592389  0.521400
# 500003  1.957878  1.432911  0.676945  2.849261  0.902924 -1.202544  0.529155
# 500004  0.318110  0.191319  1.317739  0.453759 -0.209570 -0.177090  1.554429
# ...          ...       ...       ...       ...       ...       ...       ...
# 549995  0.600980  1.173203  0.967225  0.826618  0.719335 -1.261557  0.531168
# 549996  0.538633  0.299339  0.053098  0.535128 -0.115665  0.645123  0.671151
# 549997  1.883531  1.002153  0.419530  1.700726  0.876175 -1.388113  0.399555
# 549998  1.253973 -0.853027 -0.595151  1.374145  0.866602  1.137384  0.260310
# 549999  0.625434 -0.642343 -1.474135  0.495465 -1.203959 -0.994924  0.422672
#
#          MET_phi   MET_rel  axial_MET
# ...

# %% [markdown]
# ## Exercise 7.1
#
# You will need to create several models and make sure they are properly trained. Write a function that takes this history and plots the values versus epoch. For every model that you train in the remainder of this lab, assess:
#
# * Has you model's performance plateaued? If not train for more epochs.
# * Compare the performance on training versus test sample. Are you over training?

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **model 1**

# %%
model = Sequential()
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# Metal device set to: Apple M2
# 2023-05-21 20:49:06.448231: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-05-21 20:49:06.448995: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_Train,y_Train, validation_split=0.1, epochs=8)
# Out:
# Epoch 1/8
# 2023-05-21 21:28:19.662784: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14063/14063 [==============================] - 71s 5ms/step - loss: 0.4303 - accuracy: 0.8015 - val_loss: 0.4305 - val_accuracy: 0.8027
# Epoch 2/8
# 14063/14063 [==============================] - 79s 6ms/step - loss: 0.4301 - accuracy: 0.8017 - val_loss: 0.4303 - val_accuracy: 0.8030
# Epoch 3/8
# 14063/14063 [==============================] - 79s 6ms/step - loss: 0.4299 - accuracy: 0.8018 - val_loss: 0.4300 - val_accuracy: 0.8037
# Epoch 4/8
# 14063/14063 [==============================] - 76s 5ms/step - loss: 0.4297 - accuracy: 0.8020 - val_loss: 0.4323 - val_accuracy: 0.8016
# Epoch 5/8
# 14063/14063 [==============================] - 58s 4ms/step - loss: 0.4296 - accuracy: 0.8018 - val_loss: 0.4313 - val_accuracy: 0.8022
# Epoch 6/8
# ...

# %%
model.evaluate(X_Test,y_Test)
score1 = model.evaluate(X_Test, y_Test, verbose=1)
print('Model Test accuracy:', score1[1])
print('Model Test loss:', score1[0])
# Out:
# ...
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4322 - accuracy: 0.7989
# Model Test accuracy: 0.7989400625228882
# Model Test loss: 0.4321800768375397

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# **model 2**

# %%
model2=Sequential()
model2.add(Dense(12, activation='selu'))
model2.add(Dense(8, activation='softmax'))
model2.add(Dense(1, activation='sigmoid'))

# %%
model2.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
history2 = model2.fit(X_Train,y_Train, validation_split=0.1, epochs=6)
# Out:
# Epoch 1/6
# 14063/14063 [==============================] - 77s 6ms/step - loss: 0.4320 - accuracy: 0.8004 - val_loss: 0.4319 - val_accuracy: 0.8019
# Epoch 2/6
# 14063/14063 [==============================] - 80s 6ms/step - loss: 0.4316 - accuracy: 0.8006 - val_loss: 0.4325 - val_accuracy: 0.8017
# Epoch 3/6
# 14063/14063 [==============================] - 78s 6ms/step - loss: 0.4313 - accuracy: 0.8010 - val_loss: 0.4316 - val_accuracy: 0.8025
# Epoch 4/6
# 14063/14063 [==============================] - 76s 5ms/step - loss: 0.4313 - accuracy: 0.8005 - val_loss: 0.4309 - val_accuracy: 0.8031
# Epoch 5/6
# 14063/14063 [==============================] - 76s 5ms/step - loss: 0.4310 - accuracy: 0.8012 - val_loss: 0.4319 - val_accuracy: 0.8022
# Epoch 6/6
# 14063/14063 [==============================] - 76s 5ms/step - loss: 0.4308 - accuracy: 0.8009 - val_loss: 0.4366 - val_accuracy: 0.7987

# %%
model2.evaluate(X_Test,y_Test)
score2 = model2.evaluate(X_Test, y_Test, verbose=1)
print('Model Test accuracy:', score2[1])
print('Model Test loss:', score2[0])
# Out:
# ...
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4382 - accuracy: 0.7949
# Model Test accuracy: 0.7948800325393677
# Model Test loss: 0.4381936490535736

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# **model 3**

# %%
model3 = Sequential()
model3.add(Dense(300, activation='relu'))
model3.add(Dropout(0.5))
model3.add(Dense(1, activation='sigmoid'))

# %%
model3.compile(loss = 'binary_crossentropy', optimizer = 'sgd', metrics = ['accuracy'])

# %%
history3 = model3.fit(X_Train,y_Train, validation_data=(X_Test,y_Test), epochs=8)
# Out:
# Epoch 1/8
# 15625/15625 [==============================] - 48s 3ms/step - loss: 0.4328 - accuracy: 0.8006 - val_loss: 0.4351 - val_accuracy: 0.7978
# Epoch 2/8
# 15625/15625 [==============================] - 48s 3ms/step - loss: 0.4325 - accuracy: 0.8007 - val_loss: 0.4350 - val_accuracy: 0.7980
# Epoch 3/8
# 15625/15625 [==============================] - 48s 3ms/step - loss: 0.4322 - accuracy: 0.8007 - val_loss: 0.4375 - val_accuracy: 0.7973
# Epoch 4/8
# 15625/15625 [==============================] - 48s 3ms/step - loss: 0.4319 - accuracy: 0.8009 - val_loss: 0.4358 - val_accuracy: 0.7979
# Epoch 5/8
# 15625/15625 [==============================] - 48s 3ms/step - loss: 0.4317 - accuracy: 0.8010 - val_loss: 0.4346 - val_accuracy: 0.7976
# Epoch 6/8
# 15625/15625 [==============================] - 48s 3ms/step - loss: 0.4315 - accuracy: 0.8012 - val_loss: 0.4354 - val_accuracy: 0.7981
# Epoch 7/8
# ...

# %%
model3.evaluate(X_Test,y_Test)
score3 = model3.evaluate(X_Test, y_Test, verbose=1)
print('Model Test accuracy:', score3[1])
print('Model Test loss:', score3[0])
# Out:
# ...
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4357 - accuracy: 0.7981
# Model Test accuracy: 0.7981200814247131
# Model Test loss: 0.43569284677505493

# %%
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# **model 4**

# %%
model4 = Sequential()
model4.add(Dense(17, kernel_initializer="random_uniform", activation='tanh'))
model4.add(Dense(36, kernel_initializer="random_uniform", activation='relu'))
model4.add(Dropout(0.5))
model4.add(Dense(72, kernel_initializer="random_uniform", activation='relu'))
model4.add(Dropout(0.5))
model4.add(Dense(36, kernel_initializer="random_uniform", activation='relu'))
model4.add(Dropout(0.5))
model4.add(Dense(1,kernel_initializer="random_uniform", activation='sigmoid'))

# %%
model4.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
history4 = model4.fit(X_Train,y_Train, validation_data=(X_Test,y_Test), epochs=10, batch_size=128, shuffle=True)
# Out:
# Epoch 1/10
# 3907/3907 [==============================] - 21s 5ms/step - loss: 0.4354 - accuracy: 0.7993 - val_loss: 0.4409 - val_accuracy: 0.7979
# Epoch 2/10
# 3907/3907 [==============================] - 21s 5ms/step - loss: 0.4347 - accuracy: 0.7996 - val_loss: 0.4459 - val_accuracy: 0.7945
# Epoch 3/10
# 3907/3907 [==============================] - 21s 5ms/step - loss: 0.4346 - accuracy: 0.7996 - val_loss: 0.4474 - val_accuracy: 0.7931
# Epoch 4/10
# 3907/3907 [==============================] - 21s 5ms/step - loss: 0.4339 - accuracy: 0.7998 - val_loss: 0.4550 - val_accuracy: 0.7887
# Epoch 5/10
# 3907/3907 [==============================] - 21s 5ms/step - loss: 0.4337 - accuracy: 0.8001 - val_loss: 0.4449 - val_accuracy: 0.7947
# Epoch 6/10
# 3907/3907 [==============================] - 21s 5ms/step - loss: 0.4336 - accuracy: 0.8000 - val_loss: 0.4464 - val_accuracy: 0.7928
# Epoch 7/10
# ...

# %%
model4.evaluate(X_Test,y_Test)
score4 = model4.evaluate(X_Test, y_Test, verbose=1)
print('Model Test accuracy:', score4[1])
print('Model Test loss:', score4[0])
# Out:
# ...
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4495 - accuracy: 0.7905
# Model Test accuracy: 0.7904800772666931
# Model Test loss: 0.44951748847961426

# %%
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 7.2
#
# Following the original paper (see lab 5), make a comparison of the performance (using ROC curves and AUC) between models trained with raw, features, and raw+features data.

# %%
X_Test_raw=np.array(Test_Sample[RawNames])
y_Test_raw=np.array(Test_Sample["signal"])

# %%
X_Test_fea=np.array(Test_Sample[FeatureNames])
y_Test_fea=np.array(Test_Sample["signal"])

# %%
X_Test=np.array(Test_Sample[VarNames[1:]])
y_Test=np.array(Test_Sample["signal"])

# %%
from sklearn.metrics import roc_curve,auc

predict_prob_raw=model.predict(X_Test_raw)

predict_classes_raw=np.argmax(predict_prob_raw,axis=1)

fpr_keras_raw, tpr_keras_raw, thresholds_keras_raw = roc_curve(y_Test_raw, predict_classes_raw)
# Out:
# 1563/1563 [==============================] - 1s 681us/step

# %%
auc_keras_raw = auc(fpr_keras_raw, tpr_keras_raw)

# %%
plt.figure()
plt.plot([0, 1], [0, 1], 'k--')
plt.title('Receiver Operating Characteristic (Raw)')
plt.plot(fpr_keras_raw, tpr_keras_raw, label='(area = {:.3f})'.format(auc_keras_raw))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')
plt.show()

# %%
predict_prob_fea=model.predict(X_Test_fea)

predict_classes_fea=np.argmax(predict_prob_fea,axis=1)

fpr_keras_fea, tpr_keras_fea, thresholds_keras_fea = roc_curve(y_Test_fea, predict_classes_fea)
# Out:
# 1563/1563 [==============================] - 1s 691us/step

# %%
auc_keras_fea = auc(fpr_keras_fea, tpr_keras_fea)

# %%
plt.figure()
plt.plot([0, 1], [0, 1], 'k--')
plt.title('Receiver Operating Characteristic (Features)')
plt.plot(fpr_keras_fea, tpr_keras_fea, label='(area = {:.3f})'.format(auc_keras_fea))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')
plt.show()

# %%
predict_prob=model.predict(X_Test)

predict_classes=np.argmax(predict_prob,axis=1)

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_Test, predict_classes)
# Out:
# 1563/1563 [==============================] - 1s 710us/step

# %%
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure()
plt.plot([0, 1], [0, 1], 'k--')
plt.title('Receiver Operating Characteristic (Overall)')
plt.plot(fpr_keras, tpr_keras, label='(area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Exercise 7.3
#
# Design and implement at least 3 different DNN models. Train them and compare performance. You may try different architectures, loss functions, and optimizers to see if there is an effect.

# %%
#done in previous cells for Exercise 7.1

# %% [markdown]
# ## Exercise 7.4
#
# Repeat exercise 4 from Lab 6, adding your best performing DNN as one of the models.
